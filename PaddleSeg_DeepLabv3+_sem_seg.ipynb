# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# %cd /mydrive/PaddleDet-Models
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# /content/gdrive/My Drive/PaddleDet-Models

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
import os
import json

def count_images(image_dir, exts={".jpg", ".jpeg", ".png", ".bmp", ".webp"}):
    image_count = 0
    for filename in os.listdir(image_dir):
        if os.path.splitext(filename.lower())[1] in exts:
            image_count += 1
    print(f"Total images: {image_count}")

count_images("datasets/sispanseg/train/images")
count_images("datasets/sispanseg/valid/images")
# Out:
# Total images: 200
# Total images: 56

# %%
import os
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# -------------------------
# PATHS
# -------------------------
RGB_DIR = "datasets/sispanseg/train/rgbmasks"
MASK_DIR = "datasets/sispanseg/train/masks"

# -------------------------
# DEBUG COLORS (RGB)
# -------------------------
COLOR_Uterus = (255, 0, 255)            # Magenta - Suction
COLOR_BG = (150, 75, 0)                 # Brown
COLOR_Grasper_1 = (255, 0, 0)           # Red - Grasper
COLOR_Grasper_2 = (139, 0, 139)         # Purple
COLOR_Harmonic_ACE = (0, 255, 0)        # Green - Harmonic_Ace
COLOR_Myoma_Screw = (0, 0, 255)         # Blue - Myoma_Screw
COLOR_Needle_Holder_1 = (255, 255, 0)   # Yellow - Needle_Holder
COLOR_Needle_Holder_2 = (255, 174, 66)  # Orange Yellow
COLOR_Trocer = (0, 255, 255)            # Cyan - Trocar

Uterus = np.array(COLOR_Uterus)
BG = np.array(COLOR_BG)
Grasper_1 = np.array(COLOR_Grasper_1)
Grasper_2 = np.array(COLOR_Grasper_2)
Harmonic_ACE = np.array(COLOR_Harmonic_ACE)
Myoma_Screw = np.array(COLOR_Myoma_Screw)
Needle_Holder_1 = np.array(COLOR_Needle_Holder_1)
Needle_Holder_2 = np.array(COLOR_Needle_Holder_2)
Trocer = np.array(COLOR_Trocer)

# -------------------------
# LOAD FILES
# -------------------------
files = [f for f in os.listdir(RGB_DIR) if f.endswith(".png")]
samples = random.sample(files, 2)

# -------------------------
# FUNCTION: decode panoptic → RGB
# -------------------------
def decode_panoptic(mask):
    h, w = mask.shape
    out = np.zeros((h, w, 3), dtype=np.uint8)

    class_id = mask // 1000
    instance_id = mask % 1000

    # Grasper (class 1)
    Grasper1 = (class_id == 1) & (instance_id == 1)
    Grasper2 = (class_id == 1) & (instance_id == 2)

    out[Grasper1] = Grasper_1
    out[Grasper2] = Grasper_2

    # Harmonic (class 2)
    Harmonic = (class_id == 2)
    out[Harmonic] = Harmonic_ACE

    # Myoma Screw (class 3)
    Myoma = (class_id == 3)
    out[Myoma] = Myoma_Screw

    # Needle Holder (class 4)
    NeedleHolder1 = (class_id == 4) & (instance_id == 1)
    NeedleHolder2 = (class_id == 4) & (instance_id == 2)

    out[NeedleHolder1] = Needle_Holder_1
    out[NeedleHolder2] = Needle_Holder_2

    # Trocer (class 5)
    trocer = (class_id == 5)
    out[trocer] = Trocer

    # Uterus (class 6)
    uterus = (class_id == 6)
    out[uterus] = Uterus

    # Bg (class 7)
    Bg = (class_id == 7)
    out[Bg] = BG

    return out

# -------------------------
# PLOT
# -------------------------
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, fname in enumerate(samples):
    rgb_path = os.path.join(RGB_DIR, fname)
    mask_path = os.path.join(MASK_DIR, fname)

    rgb = cv2.cvtColor(cv2.imread(rgb_path), cv2.COLOR_BGR2RGB)
    panoptic = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)

    decoded = decode_panoptic(panoptic)

    axes[i*2].imshow(rgb)
    axes[i*2].set_title(f"RGB Mask")
    axes[i*2].axis("off")

    axes[i*2+1].imshow(decoded)
    axes[i*2+1].set_title(f"Decoded Panoptic")
    axes[i*2+1].axis("off")

plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def convert_to_semantic(src_dir, dest_dir):
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    files = [f for f in os.listdir(src_dir) if f.endswith(".png")]
    print(f"Converting {len(files)} masks from {src_dir}...")

    for fname in tqdm(files):
        mask_path = os.path.join(src_dir, fname)
        # Load the panoptic mask (class * 1000 + instance)
        panoptic = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)

        # Get the class IDs
        class_id = panoptic // 1000

        # Initialize output grayscale mask (background/void = 255)
        semantic = np.full(panoptic.shape, 255, dtype=np.uint8)

        # 1. Map all THING classes to 0
        semantic[(class_id >= 1) & (class_id <= 5)] = 0

        # 2. Map STUFF classes to contiguous IDs starting from 1
        # Uterus (6) -> 1, BG (7) -> 2
        semantic[class_id == 6] = 1
        semantic[class_id == 7] = 2

        # Save as 8-bit grayscale PNG
        cv2.imwrite(os.path.join(dest_dir, fname), semantic)

# Convert Train and Val
convert_to_semantic("datasets/sispanseg/train/masks", "datasets/sispanseg/train/sem_seg")
convert_to_semantic("datasets/sispanseg/valid/masks", "datasets/sispanseg/valid/sem_seg")

# %%
import os
import json

def count_images(image_dir, exts={".jpg", ".jpeg", ".png", ".bmp", ".webp"}):
    image_count = 0
    for filename in os.listdir(image_dir):
        if os.path.splitext(filename.lower())[1] in exts:
            image_count += 1
    print(f"Total images: {image_count}")

count_images("datasets/sispanseg/train/sem_seg")
count_images("datasets/sispanseg/valid/sem_seg")
# Out:
# Total images: 200
# Total images: 56

# %%
from pathlib import Path

root_path = Path(r'/content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train')

images_path = root_path/'images'
masks_path = root_path/'sem_seg'

train_txt = open(root_path/'train.txt', 'w')

for mask_path in masks_path.rglob('*.png'):
    train_txt.write(f'{images_path}/{mask_path.stem}.jpg {masks_path}/{mask_path.name} \n')
train_txt.close()

# %%
from pathlib import Path

root_path = Path(r'/content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid')

images_path = root_path/'images'
masks_path = root_path/'sem_seg'

val_txt = open(root_path/'val.txt', 'w')

for mask_path in masks_path.rglob('*.png'):
    val_txt.write(f'{images_path}/{mask_path.stem}.jpg {masks_path}/{mask_path.name} \n')
val_txt.close()

# %%
# !git clone https://github.com/PaddlePaddle/PaddleSeg.git
# %cd PaddleSeg
# Out:
# fatal: destination path 'PaddleSeg' already exists and is not an empty directory.
# /content/gdrive/My Drive/PaddleDet-Models/PaddleSeg

# %%
# !pip install paddlepaddle-gpu pyclipper attrdict gdown -qqq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 893.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 41.8 MB/s eta 0:00:00

# %%
# !pip install -v -e .

# %%
# Force the "bridge" version of NumPy that works for both Python 3.12 and Paddle
# !pip install numpy==1.26.4 --force-reinstall

# Re-install OpenCV without dependencies to stop it from fighting with NumPy
# !pip install opencv-python-headless --no-deps --force-reinstall

# %%
# !python -c "import paddle; print(paddle.__version__); print(paddle.device.get_device()); import paddleseg; print(paddleseg.__version__)"
# Out:
# 2.6.2
# gpu:0
# 0.0.0.dev0

# %%
# !python tools/predict.py --help

# %%
# !python tools/predict.py \
       --config configs/deeplabv3p/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k.yml \
       --model_path https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams \
       --device gpu \
       --image_path /content/gdrive/MyDrive/Pytorch-Models/datasets/cityscapes-tests/ \
       --save_dir output/deeplabv3p_results
# Out:
# [2026/05/03 14:21:46] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/03 14:21:46] INFO:
# ---------------Config Information---------------
# batch_size: 2
# iters: 80000
# train_dataset:
#   dataset_root: data/cityscapes
#   mode: train
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Cityscapes
# val_dataset:
#   dataset_root: data/cityscapes
#   mode: val
#   transforms:
#   - type: Normalize
#   type: Cityscapes
# optimizer:
#   momentum: 0.9
#   type: SGD
#   weight_decay: 4.0e-05
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 19
#   pretrained: null
#   type: DeepLabV3P
# ------------------------------------------------
#
# [2026/05/03 14:21:46] INFO: Set device: gpu:0
# [2026/05/03 14:21:46] WARNING: Add the `in_channels` in train_dataset class to model config. We suggest you manually set `in_channels` in model config.
# [2026/05/03 14:21:46] INFO: Use the following config to build model
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     in_channels: 3
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 19
#   pretrained: null
#   type: DeepLabV3P
# W0503 14:21:46.089629 12685 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0503 14:21:46.089677 12685 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/03 14:21:46] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# Connecting to https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# Downloading resnet50_vd_ssld_v2.tar.gz
# [==================================================] 100.00%
# Uncompress resnet50_vd_ssld_v2.tar.gz
# [==================================================] 100.00%
# [2026/05/03 14:22:15] INFO: There are 275/275 variables loaded into ResNet_vd.
# [2026/05/03 14:22:17] INFO: The number of images: 6
# [2026/05/03 14:22:17] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# Connecting to https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# Downloading model.pdparams
# [==================================================] 100.00%
# [2026/05/03 14:22:49] INFO: There are 360/360 variables loaded into DeepLabV3P.
# [2026/05/03 14:22:49] INFO: Start to predict...
# 6/6 [==============================] - 30s 5s/step
# [2026/05/03 14:23:19] INFO: Predicted images are saved in output/deeplabv3p_results/added_prediction and output/deeplabv3p_results/pseudo_color_prediction .

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('output/deeplabv3p_results/pseudo_color_prediction/cityscapes4.png')

plt.figure("Image")
plt.imshow(img)
plt.show()

# %%
# !ls configs/deeplabv3p/
# Out:
# deeplabv3p_resnet101_os8_cityscapes_1024x512_80k.yml
# deeplabv3p_resnet101_os8_cityscapes_769x769_80k.yml
# deeplabv3p_resnet101_os8_voc12aug_512x512_40k.yml
# deeplabv3p_resnet50_os8_cityscapes_1024x512_80k_rmiloss.yml
# deeplabv3p_resnet50_os8_cityscapes_1024x512_80k.yml
# deeplabv3p_resnet50_os8_voc12aug_512x512_40k.yml
# deeplabv3p_uterus.yml
# README.md

# %%
one_epoch = 200/4
print(one_epoch)
total_iters = one_epoch * 20
print(total_iters)
# Out:
# 50.0
# 1000.0

# %%
custom_cfg = """
batch_size: 4
iters: 1000

train_dataset:
  type: Dataset
  dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
  train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
  num_classes: 3
  transforms:
    - type: ResizeStepScaling
      min_scale_factor: 0.5
      max_scale_factor: 2.0
      scale_step_size: 0.25
    - type: RandomPaddingCrop
      crop_size: [1024, 512]
    - type: RandomHorizontalFlip
    - type: RandomDistort
      brightness_range: 0.4
      contrast_range: 0.4
      saturation_range: 0.4
    - type: Normalize
  mode: train

val_dataset:
  type: Dataset
  dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
  val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
  num_classes: 3
  transforms:
    - type: Normalize
  mode: val

model:
  type: DeepLabV3P
  backbone:
    type: ResNet50_vd
    output_stride: 8
    multi_grid: [1, 2, 4]
    pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
  num_classes: 3
  backbone_indices: [0, 3]
  aspp_ratios: [1, 12, 24, 36]
  aspp_out_channels: 256
  align_corners: False
  pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams

optimizer:
  type: SGD
  momentum: 0.9
  weight_decay: 4.0e-5

lr_scheduler:
  type: PolynomialDecay
  learning_rate: 0.01
  end_lr: 0
  power: 0.9

loss:
  types:
    - type: CrossEntropyLoss
  coef: [1]
"""

with open('configs/deeplabv3p/deeplabv3p_uterus.yml', 'w') as f:
    f.write(custom_cfg)

# %%
# !python tools/train.py --help

# usage: train.py [-h] [--config CONFIG] [--device {cpu,gpu,xpu,npu,mlu}]
#                 [--save_dir SAVE_DIR] [--num_workers NUM_WORKERS] [--do_eval]
#                 [--use_vdl] [--use_ema] [--resume_model RESUME_MODEL]
#                 [--iters ITERS] [--batch_size BATCH_SIZE]
#                 [--learning_rate LEARNING_RATE]
#                 [--save_interval SAVE_INTERVAL] [--log_iters LOG_ITERS]
#                 [--keep_checkpoint_max KEEP_CHECKPOINT_MAX]
#                 [--early_stop_intervals EARLY_STOP_INTERVALS] [--seed SEED]
#                 [--precision {fp32,fp16}] [--amp_level {O1,O2}]
#                 [--profiler_options PROFILER_OPTIONS]
#                 [--data_format DATA_FORMAT] [--repeats REPEATS]
#                 [--opts OPTS [OPTS ...]] [--use_multilabel]
#                 [--to_static_training] [--output_op {argmax,softmax,none}]
#                 [--input_shape INPUT_SHAPE [INPUT_SHAPE ...]] [--for_fd]

# %%
# !python tools/train.py \
       --config configs/deeplabv3p/deeplabv3p_uterus.yml \
       --device gpu \
       --num_workers 8 \
       --do_eval \
       --use_vdl \
       --save_interval 100 \
       --log_iters 5 \
       --keep_checkpoint_max 2 \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus
# Out:
# [2026/05/03 14:30:20] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/03 14:30:20] INFO:
# ---------------Config Information---------------
# batch_size: 4
# iters: 1000
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   momentum: 0.9
#   type: SGD
#   weight_decay: 4.0e-05
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# ------------------------------------------------
#
# [2026/05/03 14:30:20] INFO: Set device: gpu
# [2026/05/03 14:30:20] INFO: Use the following config to build model
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# W0503 14:30:20.749825 15004 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0503 14:30:20.749886 15004 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/03 14:30:21] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# [2026/05/03 14:30:21] INFO: There are 275/275 variables loaded into ResNet_vd.
# [2026/05/03 14:30:22] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# [2026/05/03 14:30:22] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.weight doesn't match.(Pretrained: [19, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/03 14:30:22] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.bias doesn't match.(Pretrained: [19], Actual: [3])
# [2026/05/03 14:30:22] INFO: There are 358/360 variables loaded into DeepLabV3P.
# [2026/05/03 14:30:22] INFO: Use the following config to build train_dataset
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# [2026/05/03 14:30:23] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/03 14:30:24] INFO: If the type is SGD and momentum in optimizer config, the type is changed to Momentum.
# [2026/05/03 14:30:24] INFO: Use the following config to build optimizer
# optimizer:
#   momentum: 0.9
#   type: Momentum
#   weight_decay: 4.0e-05
# [2026/05/03 14:30:24] INFO: Use the following config to build loss
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# /usr/local/lib/python3.12/dist-packages/paddle/nn/layer/norm.py:824: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# [2026/05/03 14:30:43] INFO: [TRAIN] epoch: 1, iter: 5/1000, loss: 1.2791, lr: 0.009964, batch_cost: 3.7709, reader_cost: 1.58455, ips: 1.0608 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 01:02:31
# [2026/05/03 14:30:53] INFO: [TRAIN] epoch: 1, iter: 10/1000, loss: 0.7575, lr: 0.009919, batch_cost: 1.9620, reader_cost: 0.00041, ips: 2.0387 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:32:22
# [2026/05/03 14:31:03] INFO: [TRAIN] epoch: 1, iter: 15/1000, loss: 0.8512, lr: 0.009874, batch_cost: 1.9940, reader_cost: 0.00089, ips: 2.0060 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:32:44
# [2026/05/03 14:31:13] INFO: [TRAIN] epoch: 1, iter: 20/1000, loss: 0.4804, lr: 0.009829, batch_cost: 2.0276, reader_cost: 0.00061, ips: 1.9728 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:33:07
# [2026/05/03 14:31:23] INFO: [TRAIN] epoch: 1, iter: 25/1000, loss: 0.7088, lr: 0.009784, batch_cost: 2.0575, reader_cost: 0.00051, ips: 1.9441 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:33:26
# [2026/05/03 14:31:34] INFO: [TRAIN] epoch: 1, iter: 30/1000, loss: 0.5053, lr: 0.009739, batch_cost: 2.0898, reader_cost: 0.00068, ips: 1.9140 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:33:47
# [2026/05/03 14:31:44] INFO: [TRAIN] epoch: 1, iter: 35/1000, loss: 0.6300, lr: 0.009693, batch_cost: 2.1286, reader_cost: 0.00092, ips: 1.8792 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:34:14
# [2026/05/03 14:31:55] INFO: [TRAIN] epoch: 1, iter: 40/1000, loss: 0.8950, lr: 0.009648, batch_cost: 2.1657, reader_cost: 0.00058, ips: 1.8470 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:34:39
# [2026/05/03 14:32:06] INFO: [TRAIN] epoch: 1, iter: 45/1000, loss: 0.8303, lr: 0.009603, batch_cost: 2.2132, reader_cost: 0.00019, ips: 1.8073 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:35:13
# [2026/05/03 14:32:17] INFO: [TRAIN] epoch: 1, iter: 50/1000, loss: 0.6844, lr: 0.009558, batch_cost: 2.2151, reader_cost: 0.00018, ips: 1.8058 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:35:04
# [2026/05/03 14:32:32] INFO: [TRAIN] epoch: 2, iter: 55/1000, loss: 0.6003, lr: 0.009513, batch_cost: 2.9847, reader_cost: 0.80156, ips: 1.3402 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:47:00
# [2026/05/03 14:32:43] INFO: [TRAIN] epoch: 2, iter: 60/1000, loss: 0.6983, lr: 0.009467, batch_cost: 2.1473, reader_cost: 0.00044, ips: 1.8628 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:33:38
# [2026/05/03 14:32:54] INFO: [TRAIN] epoch: 2, iter: 65/1000, loss: 0.4924, lr: 0.009422, batch_cost: 2.1467, reader_cost: 0.00022, ips: 1.8633 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00:33:27
# [2026/05/03 14:33:04] INFO: [TRAIN] epoch: 2, iter: 70/1000, loss: 0.3743, lr: 0.009377, batch_cost: 2.1453, reader_cost: 0.00024, ips: 1.8646 samples/sec, max_mem_reserved: 12927 MB, max_mem_allocated: 11732 MB | ETA 00
INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 37s 660ms/step - batch_cost: 0.6599 - reader cost: 0.0056
# [2026/05/03 15:15:26] INFO: [EVAL] #Images: 56 mIoU: 0.9106 Acc: 0.9649 Kappa: 0.9308 Dice: 0.9529
# [2026/05/03 15:15:26] INFO: [EVAL] Class IoU:
# [0.8745 0.9058 0.9517]
# [2026/05/03 15:15:26] INFO: [EVAL] Class Precision:
# [0.9377 0.9346 0.9824]
# [2026/05/03 15:15:26] INFO: [EVAL] Class Recall:
# [0.9284 0.9671 0.9683]
# [2026/05/03 15:15:28] INFO: [EVAL] The model with the best validation mIoU (0.9106) was saved at iter 1000.
# <class 'paddle.nn.layer.pooling.AvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.pooling.MaxPool2D'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddleseg.models.layers.activation.Activation'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddleseg.models.layers.wrap_functions.Add'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.common.Dropout'>'s flops has been counted
# Total Flops: 228305504768     Total Params: 26790131

# %%
# 0.9106

# %%
# !python tools/train.py \
#        --config configs/deeplabv3p/deeplabv3p_uterus.yml \
#        --device gpu \
#        --num_workers 8 \
#        --do_eval \
#        --use_vdl \
#        --resume_model /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/iter_1000 \
#        --iters 2000 \
#        --save_interval 100 \
#        --log_iters 5 \
#        --keep_checkpoint_max 2 \
#        --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus

# %%
# !python tools/val.py --help

# usage: val.py [-h] [--config CONFIG] [--model_path MODEL_PATH]
#               [--num_workers NUM_WORKERS] [--device {cpu,gpu,xpu,npu,mlu}]
#               [--aug_eval] [--scales SCALES [SCALES ...]] [--flip_horizontal]
#               [--flip_vertical] [--is_slide] [--crop_size CROP_SIZE CROP_SIZE]
#               [--stride STRIDE STRIDE] [--data_format DATA_FORMAT]
#               [--auc_roc AUC_ROC] [--opts OPTS [OPTS ...]] [--use_multilabel]

# %%
# !python tools/val.py \
       --config configs/deeplabv3p/deeplabv3p_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/best_model/model.pdparams \
       --device gpu \
       --num_workers 8
# Out:
# [2026/05/03 15:18:02] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/03 15:18:02] INFO:
# ---------------Config Information---------------
# batch_size: 4
# iters: 1000
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   momentum: 0.9
#   type: SGD
#   weight_decay: 4.0e-05
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# ------------------------------------------------
#
# [2026/05/03 15:18:02] INFO: Set device: gpu
# [2026/05/03 15:18:02] INFO: Use the following config to build model
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# W0503 15:18:02.932788 28584 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0503 15:18:02.932826 28584 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/03 15:18:03] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# [2026/05/03 15:18:05] INFO: There are 275/275 variables loaded into ResNet_vd.
# [2026/05/03 15:18:05] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# [2026/05/03 15:18:06] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.weight doesn't match.(Pretrained: [19, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/03 15:18:06] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.bias doesn't match.(Pretrained: [19], Actual: [3])
# [2026/05/03 15:18:06] INFO: There are 358/360 variables loaded into DeepLabV3P.
# [2026/05/03 15:18:06] INFO: Loading pretrained model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/best_model/model.pdparams
# [2026/05/03 15:18:07] INFO: There are 360/360 variables loaded into DeepLabV3P.
# [2026/05/03 15:18:07] INFO: Loaded trained weights successfully.
# [2026/05/03 15:18:07] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/03 15:18:07] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 37s 664ms/step - batch_cost: 0.6636 - reader cost: 0.0253
# [2026/05/03 15:18:44] INFO: [EVAL] #Images: 56 mIoU: 0.9106 Acc: 0.9649 Kappa: 0.9308 Dice: 0.9529
# [2026/05/03 15:18:44] INFO: [EVAL] Class IoU:
# [0.8745 0.9058 0.9517]
# [2026/05/03 15:18:44] INFO: [EVAL] Class Precision:
# [0.9377 0.9346 0.9824]
# [2026/05/03 15:18:44] INFO: [EVAL] Class Recall:
# [0.9284 0.9671 0.9683]

# %%
# !python tools/predict.py \
       --config configs/deeplabv3p/deeplabv3p_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/best_model/model.pdparams \
       --device gpu \
       --image_path /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/images \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/infer_images/
# Out:
# [2026/05/03 15:19:02] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/03 15:19:02] INFO:
# ---------------Config Information---------------
# batch_size: 4
# iters: 1000
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   momentum: 0.9
#   type: SGD
#   weight_decay: 4.0e-05
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# ------------------------------------------------
#
# [2026/05/03 15:19:02] INFO: Set device: gpu:0
# [2026/05/03 15:19:02] INFO: Use the following config to build model
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# W0503 15:19:02.577806 28910 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0503 15:19:02.577872 28910 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/03 15:19:02] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# [2026/05/03 15:19:03] INFO: There are 275/275 variables loaded into ResNet_vd.
# [2026/05/03 15:19:03] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# [2026/05/03 15:19:04] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.weight doesn't match.(Pretrained: [19, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/03 15:19:04] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.bias doesn't match.(Pretrained: [19], Actual: [3])
# [2026/05/03 15:19:04] INFO: There are 358/360 variables loaded into DeepLabV3P.
# [2026/05/03 15:19:04] INFO: The number of images: 56
# [2026/05/03 15:19:04] INFO: Loading pretrained model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/best_model/model.pdparams
# [2026/05/03 15:19:05] INFO: There are 360/360 variables loaded into DeepLabV3P.
# [2026/05/03 15:19:05] INFO: Start to predict...
# 56/56 [==============================] - 47s 832ms/step
# [2026/05/03 15:19:51] INFO: Predicted images are saved in /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/infer_images/added_prediction and /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/infer_images/pseudo_color_prediction .

# %%
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import cv2
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/infer_images/pseudo_color_prediction"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 2 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !python tools/export.py \
       --config configs/deeplabv3p/deeplabv3p_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/best_model/model.pdparams \
       --save_dir output_inference/deeplabv3p_uterus
# Out:
# [2026/05/03 15:20:36] INFO: Use the following config to build model
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# W0503 15:20:36.371459 29370 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0503 15:20:36.372496 29370 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/03 15:20:36] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
# [2026/05/03 15:20:37] INFO: There are 275/275 variables loaded into ResNet_vd.
# [2026/05/03 15:20:37] INFO: Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
# [2026/05/03 15:20:38] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.weight doesn't match.(Pretrained: [19, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/03 15:20:38] WARNING: [SKIP] Shape of pretrained params head.decoder.conv.bias doesn't match.(Pretrained: [19], Actual: [3])
# [2026/05/03 15:20:38] INFO: There are 358/360 variables loaded into DeepLabV3P.
# [2026/05/03 15:20:38] INFO: Loaded trained params successfully.
# [2026/05/03 15:20:38] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/03 15:20:38] INFO:
# ---------------Config Information---------------
# batch_size: 4
# iters: 1000
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   momentum: 0.9
#   type: SGD
#   weight_decay: 4.0e-05
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# loss:
#   coef:
#   - 1
#   types:
#   - type: CrossEntropyLoss
# model:
#   align_corners: false
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet50_vd_ssld_v2.tar.gz
#     type: ResNet50_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 3
#   pretrained: https://bj.bcebos.com/paddleseg/dygraph/cityscapes/deeplabv3p_resnet50_os8_cityscapes_1024x512_80k/model.pdparams
#   type: DeepLabV3P
# ------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/paddle/jit/api.py:310: UserWarning: full_graph=False is not supported in Python 3.12+. Set full_graph=True automatically
#   warnings.warn(
# I0503 15:20:46.590372 29370 program_interpreter.cc:212] New Executor is Running.
# [2026/05/03 15:20:47] INFO:
# ---------------Deploy Information---------------
# Deploy:
#   input_shape:
#   - -1
#   - 3
#   - -1
#   - -1
#   model: model.pdmodel
#   output_dtype: int32
#   output_op: argmax
#   params: model.pdiparams
#   transforms:
#   - type: Normalize
#
# [2026/05/03 15:20:47] INFO: The inference model is saved in output_inference/deeplabv3p_uterus

# %%
def normalize(img, mean, std):
    img = img / 255.0
    mean = np.array(mean)[np.newaxis, np.newaxis, :]
    std = np.array(std)[np.newaxis, np.newaxis, :]
    img -= mean
    img /= std
    return img

def preprocess(img, img_size):
    mean = [0.5, 0.5, 0.5]
    std = [0.5, 0.5, 0.5]
    img = cv2.resize(img, (img_size[0], img_size[1]))
    img = img[:, :, ::-1].astype('float32')  # bgr -> rgb
    img = normalize(img, mean, std)
    img = img.transpose((2, 0, 1))  # hwc -> chw
    return img[np.newaxis, :]

# %%
import paddle
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
import paddle.inference as paddle_infer
import cv2
import numpy as np

config = paddle_infer.Config("output_inference/deeplabv3p_uterus/model.pdmodel", "output_inference/deeplabv3p_uterus/model.pdiparams")
config.enable_use_gpu(100, 0)
predictor = paddle_infer.create_predictor(config)

img = cv2.imread("/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/Laparoscopic-Myomectomy-with-Baseball-Suturing-22-_jpg.rf.04929e16d4ace3507c937c4e1ce8a333.jpg")
im_size = [1024, 512]
data = preprocess(img, im_size)

input_names = predictor.get_input_names()
input_tensor = predictor.get_input_handle(input_names[0])
input_tensor.reshape(img.shape)
input_tensor.copy_from_cpu(data.copy())

predictor.run()
output_names = predictor.get_output_names()
output_tensor = predictor.get_output_handle(output_names[0])
output_data = output_tensor.copy_to_cpu()
print(output_data.shape)
# Out:
# (1, 512, 1024)

# %%
CATEGORY_COLORS = {
    0: [0, 0, 0],           # Things (Black)
    1: [255, 0, 255],       # Uterus (Magenta)
    2: [0, 75, 150],        # BG (Brown)
}
orig_h, orig_w = img.shape[:2]

# 1. Create a color palette array (fast lookup)
palette_map = np.zeros((256, 3), dtype=np.uint8)
for i, color in CATEGORY_COLORS.items():
    palette_map[i] = color

# 2. Apply the colors in one vectorized step
mask = output_data[0].squeeze().astype(np.uint8)
color_mask = palette_map[mask] # Instant mapping

color_mask = cv2.resize(color_mask, (orig_w, orig_h))

# 3. Create a fast overlay
overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import numpy as np
import os
import random
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 3 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)
    data = preprocess(img, im_size)

    input_names = predictor.get_input_names()
    input_tensor = predictor.get_input_handle(input_names[0])
    input_tensor.reshape(img.shape)
    input_tensor.copy_from_cpu(data.copy())

    predictor.run()
    output_names = predictor.get_output_names()
    output_tensor = predictor.get_output_handle(output_names[0])
    output_data = output_tensor.copy_to_cpu()

    orig_h, orig_w = img.shape[:2]

    mask = output_data[0].squeeze().astype(np.uint8)
    color_mask = palette_map[mask] # Instant mapping

    color_mask = cv2.resize(color_mask, (orig_w, orig_h))
    overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !pip install onnx onnxscript paddle2onnx==1.1.0
# Out:
# Collecting onnx
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxscript
#   Downloading onnxscript-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting paddle2onnx==1.1.0
#   Downloading paddle2onnx-1.1.0-cp312-cp312-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (477 bytes)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-0.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.1)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Downloading paddle2onnx-1.1.0-cp312-cp312-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 16.4 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 97.2 MB/s eta 0:00:00
# Downloading onnxscript-0.7.0-py3-none-any.whl (714 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 66.1 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.1-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.8/166.8 kB 21.0 MB/s eta 0:00:00
# Installing collected packages: paddle2onnx, onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.21.0 onnx_ir-0.2.1 onnxscript-0.7.0 paddle2onnx-1.1.0

# %%
# !pip install onnxruntime-gpu
# Out:
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Downloading onnxruntime_gpu-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (271.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.3/271.3 MB 4.9 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.25.1

# %%
# !paddle2onnx --model_dir=./output_inference/deeplabv3p_uterus/ \
            --model_filename model.pdmodel  \
            --params_filename model.pdiparams \
            --opset_version 16 \
            --save_file /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/deeplabv3p_uterus.onnx
# Out:
# [Paddle2ONNX] Start to parse PaddlePaddle model...
# [Paddle2ONNX] Model file path: ./output_inference/deeplabv3p_uterus/model.pdmodel
# [Paddle2ONNX] Paramters file path: ./output_inference/deeplabv3p_uterus/model.pdiparams
# [Paddle2ONNX] Start to parsing Paddle model...
# [Paddle2ONNX] Use opset_version = 16 for ONNX export.
# [Paddle2ONNX] PaddlePaddle model is exported as ONNX format now.
# 2026-05-03 15:22:58 [INFO]	===============Make PaddlePaddle Better!================
# 2026-05-03 15:22:58 [INFO]	A little survey: https://iwenjuan.baidu.com/?code=r8hu2s

# %%
# %ls /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/
# Out:
# best_model/             infer_images/  iter_900/
# deeplabv3p_uterus.onnx  iter_1000/     vdlrecords.1777818624.log

# %%
import onnxruntime
import numpy as np
import cv2
import torch

# Load image and preprocess
img_path = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/Laparoscopic-Myomectomy-with-Baseball-Suturing-22-_jpg.rf.04929e16d4ace3507c937c4e1ce8a333.jpg"

mean = np.array([0.5, 0.5, 0.5], dtype=np.float32)
std = np.array([0.5, 0.5, 0.5], dtype=np.float32)

img = cv2.imread(img_path)
img_resized = cv2.resize(img, (1024, 512))
img_input = img_resized[:, :, ::-1].astype(np.float32) / 255.0
img_input = (img_input - mean) / std
img_input = img_input.transpose(2, 0, 1)[np.newaxis, :]  # (1, 3, H, W)

# Run inference
session = onnxruntime.InferenceSession("/content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/deeplabv3p_uterus/deeplabv3p_uterus.onnx", providers=["CUDAExecutionProvider"])
input_name = session.get_inputs()[0].name
outputs = session.run(None, {input_name: img_input})

# Inspect inputs to confirm names and shapes (for debugging)
input_names = [inp.name for inp in session.get_inputs()]
print("Expected input names from ONNX model:", input_names)
print("Output:", [o.shape for o in outputs])
# Out:
# Expected input names from ONNX model: ['x']
# Output: [(1, 512, 1024)]

# %%
print(outputs[0])
# Out:
# [[[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]]

# %%
CATEGORY_COLORS = {
    0: [0, 0, 0],           # Things (Black)
    1: [255, 0, 255],       # Uterus (Magenta)
    2: [0, 75, 150],        # BG (Brown)
}
orig_h, orig_w = img.shape[:2]

# 1. Create a color palette array (fast lookup)
palette_map = np.zeros((256, 3), dtype=np.uint8)
for i, color in CATEGORY_COLORS.items():
    palette_map[i] = color

# 2. Apply the colors in one vectorized step
mask = outputs[0].squeeze().astype(np.uint8) # outputs[0] is already the class map, argmax is not needed
color_mask = palette_map[mask] # Instant mapping

color_mask = cv2.resize(color_mask, (orig_w, orig_h))

# 3. Create a fast overlay
overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import numpy as np
import os
import random
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 3 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)
    img_resized = cv2.resize(img, (1024, 512))
    img_input = img_resized[:, :, ::-1].astype(np.float32) / 255.0
    img_input = (img_input - mean) / std
    img_input = img_input.transpose(2, 0, 1)[np.newaxis, :]  # (1, 3, H, W)

    outputs = session.run(None, {input_name: img_input})

    orig_h, orig_w = img.shape[:2]

    mask = outputs[0].squeeze().astype(np.uint8)
    color_mask = palette_map[mask] # Instant mapping

    color_mask = cv2.resize(color_mask, (orig_w, orig_h))
    overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()
